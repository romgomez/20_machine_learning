# %%
#Import dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#Import warnings to eliminate warning error when testing classifiers 
def warn(*args, **kwargs): pass
import warnings
warnings.warn = warn

# Importing classifiers
from sklearn.metrics import accuracy_score, log_loss
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier as RFC

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("cumulative.csv")
df = df.drop(columns=["rowid", "kepid", "kepoi_name", "kepler_name", "koi_pdisposition", "koi_score", "koi_tce_delivname"])
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1       CONFIRMED              0              0              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3  FALSE POSITIVE              0              1              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0    9.488036     2.775000e-05    -2.775000e-05   170.538750
# 1   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 2   19.899140     1.494000e-05    -1.494000e-05   175.850252
# 3    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 4    2.525592     3.761000e-06    -3.761000e-06   171.595550
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
data = df.drop("koi_disposition", axis=1)
data.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0    9.488036
# 1              0              0              0              0   54.418383
# 2              0              1              0              0   19.899140
# 3              0              1              0              0    1.736952
# 4              0              0              0              0    2.525592
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.775000e-05    -2.775000e-05   170.538750          0.002160
# 1     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 2     1.494000e-05    -1.494000e-05   175.850252          0.000581
# 3     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 4     3.761000e-06    -3.761000e-06   171.595550          0.001130
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
X = data
y = df["koi_disposition"].values.reshape(-1, 1)

print(X.shape,y.shape)
# Out:
# (8744, 40) (8744, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6274              0              0              0              0  492.252990
# 3541              0              0              0              0   49.567408
# 8659              1              0              0              0  452.100930
# 4851              0              1              0              0   18.645329
# 1387              0              0              0              0    5.184990
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6274         0.011050        -0.011050   520.860000           0.01800
# 3541         0.000187        -0.000187   169.542270           0.00322
# 8659         0.054070        -0.054070   460.488400           0.05070
# 4851         0.000002        -0.000002   147.207512           0.00007
# 1387         0.000012        -0.000012   131.881400           0.00185
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from keras.utils import to_categorical

X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)


# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y)
encoded_y = label_encoder.transform(y)

# Step 2: One-hot encoding
one_hot_y = to_categorical(encoded_y)
one_hot_y
# Out:
# Using TensorFlow backend.
# array([[0., 1., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.],
#        ...,
#        [1., 0., 0.],
#        [0., 0., 1.],
#        [0., 0., 1.]], dtype=float32)

# %%
#Preliminary testing of classifiers fit to data (not scaled)
classifiers = [
    LogisticRegression(),
    KNeighborsClassifier(3),
    SVC(kernel="rbf", C=0.025, probability=True),
    DecisionTreeClassifier(),
    RandomForestClassifier()]

# Logging for Visual Comparison
log_cols=["Classifier", "Accuracy", "Log Loss"]
log = pd.DataFrame(columns=log_cols)

for clf in classifiers:
    clf.fit(X_train, y_train)
    name = clf.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = clf.predict(X_test)
    acc = accuracy_score(y_test, train_predictions)
    print("Accuracy: {:.4%}".format(acc))
    
    train_predictions = clf.predict_proba(X_test)
    ll = log_loss(y_test, train_predictions)
    
    log_entry = pd.DataFrame([[name, acc*100, ll]], columns=log_cols)
    log = log.append(log_entry)
    
print("="*30)
# Out:
# ...
# LogisticRegression
# ****Results****
# Accuracy: 66.4227%
# ...
# KNeighborsClassifier
# ****Results****
# Accuracy: 64.0897%
# ...
# SVC
# ****Results****
# Accuracy: 50.4575%
# ...
# DecisionTreeClassifier
# ****Results****
# Accuracy: 84.6295%
# ...
# RandomForestClassifier
# ****Results****
# Accuracy: 87.7402%
# ...

# %%
# Plotting model accuracy for a few classifiers
sns.set_color_codes("muted")
sns.barplot(x='Accuracy', y='Classifier', data=log, color="b")

plt.xlabel('Accuracy %')
plt.title('Classifier Accuracy')
plt.show()

# %% [markdown]
# # Train the Support Vector Machine

# %%
# Train support vector machine linear classifier, fit to the training data, and validate with the test data
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model
model.fit(X_train_scaled, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
# SVM Model Accuracy
print(f"Training Data Score: {model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8584934431229033
# Testing Data Score: 0.8522415370539799

# %% [markdown]
# # Logistic Regression

# %%
# Train and test Logistic Regression model
from sklearn.linear_model import LogisticRegression
log_reg_model = LogisticRegression()
log_reg_model
log_reg_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Logisitics Regression Model Accuracy
print(f"Training Data Score: {log_reg_model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {log_reg_model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8494967978042086
# Testing Data Score: 0.8444647758462946

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.svm import SVC 
rfc_model = RFC()
rfc_model
rfc_model.fit(X_train_scaled, y_train)

# Logisitics Regression Model Accuracy
print(f"Training Data Score: {rfc_model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {rfc_model.score(X_test_scaled, y_test)}")

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the `C` and `gamma` parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10],
              'gamma': [0.0001, 0.001, 0.01]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Train the model with GridSearch
# Fit the model using the grid search estimator. 
# This will take the SVC model and try each combination of parameters
grid.fit(X_train_scaled, y_train)

# %%
#Determine the best parameters and highest accuracy
print(grid.best_params_)
print(grid.best_score_)

# %%
# Make predictions with the hypertuned model
predictions = grid.predict(X_test)
predictions

# %%
# Calculate classification report for SVC hypertuned model
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                            target_names=["CONFIRMED", "FALSE POSITIVE","CANDIDATE"]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-3b82606aa46b> in <module>
#       1 # Calculate classification report for SVC hypertuned model
#       2 from sklearn.metrics import classification_report
# ----> 3 print(classification_report(y_test, predictions,
#       4                             target_names=["CONFIRMED", "FALSE POSITIVE","CANDIDATE"]))
#
# NameError: name 'predictions' is not defined

# %%
# Calculate classification report for SVC hypertuned model
from sklearn.metrics import classification_report
predictions = log_reg_model.predict(X_test)
print(classification_report(y_test, predictions,
                            target_names=["CONFIRMED", "FALSE POSITIVE","CANDIDATE"]))
